# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Dropout, Flatten , Convolution2D, MaxPooling2D , Lambda, Conv2D, Activation,Concatenate, Input, BatchNormalization
from tensorflow.keras.optimizers import Adam , SGD , Adagrad
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers , initializers, activations
import tensorflow.keras.backend as K
from sklearn.preprocessing import StandardScaler
from joblib import dump, load
import tensorflow_probability as tfp

import numpy as np
import matplotlib.pyplot as plt
import corner
import os 
import sys
import time
import importlib
import logging
from tqdm import tqdm

importlib.reload(logging)
logging.basicConfig(level = logging.INFO)

# limit GPU memory
gpus = tf.config.experimental.list_physical_devices('GPU')
try:
    tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
    tf.config.experimental.set_virtual_device_configuration(
    gpus[0],
    [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=10000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
except RuntimeError as e:
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPU

# %% [markdown]
# Ref: https://agustinus.kristia.de/techblog/2016/12/17/conditional-vae/
# Ref: https://keras.io/guides/customizing_what_happens_in_fit/
# Ref: https://keras.io/examples/generative/vae/
# Ref: https://github.com/hagabbar/VItamin/blob/c1ae6dfa27b8ab77193caacddd477fde0dece1c2/Models/VICI_inverse_model.py#L404
# Ref: https://www.tensorflow.org/probability/api_docs/python/tfp/distributions/MultivariateNormalDiag

# %%
def angle_transform(prediction_array: np.ndarray = 0)-> np.ndarray :
    tmp = np.arctan2(prediction_array[:,0],prediction_array[:,1])
    tmp = np.where(tmp >= 0 , tmp, 2*np.pi+tmp) 
    delta = tmp/np.pi*180     
    return delta

def feature_reshape(data,column=2):
    tmp = data.reshape(len(data),column,36)
    tmp = np.array([ element.T for element in tmp])
    return tmp

# %%
# %%time
training_data = np.load("./nsi_data/sample_nsi_regression_1e7_v1.npz")
data_all = np.column_stack([training_data['ve_dune'][:,:36], training_data['vu_dune'][:,:36], training_data['vebar_dune'][:,:36], training_data['vubar_dune'][:,:36]])

scaler = StandardScaler()
scaler.fit(data_all)

target = np.column_stack([training_data["theta23"], training_data["delta"]/180*np.pi ])
# target = target/180*np.pi 

x_train = data_all[:9000000]/1000
y_train = target[:9000000]
y_train_delta = np.column_stack([np.sin(y_train[:,1]), np.cos(y_train[:,1])]) 
y_train_theta23 = y_train[:,0]

x_test = data_all[9000000:]/1000
y_test = target[9000000:]
y_test_delta = np.column_stack([np.sin(y_test[:,1]), np.cos(y_test[:,1])]) 
y_test_theta23 = y_test[:,0]
# Out:
# CPU times: user 40.2 s, sys: 12.8 s, total: 53 s
# Wall time: 1min 2s

# %%
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
latent_dim = 7

"""
Encoder 1 (parameter + spectrum)
"""
# parameter
encoder_parameter_inputs = layers.Input(shape=(2,),name = 'encoder_parameter_inputs')
x_parameter = layers.Dense(64, activation="relu", name = 'dense_parameter_1')(encoder_parameter_inputs)
x_parameter = layers.Dense(32, activation="relu", name = 'dense_parameter_2')(x_parameter)
x_parameter = layers.Dense(16, activation="relu", name = 'dense_parameter_3')(x_parameter)

# spectrum
encoder_spectrum_inputs = layers.Input(shape=(144),name = 'encoder_spectrum_inputs')
x_spectrum = layers.Dense(64, activation="relu", name = 'dense_spectrum_1')(encoder_spectrum_inputs)
x_spectrum = layers.Dense(32, activation="relu", name = 'dense_spectrum_2')(x_spectrum)
x_spectrum = layers.Dense(16, activation="relu", name = 'dense_spectrum_3')(x_spectrum)

# merged
mergedOut_Encoder_1 = Concatenate()([x_parameter,x_spectrum])

# sampling
z_mean = layers.Dense(latent_dim, name="z_mean")(mergedOut_Encoder_1)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(mergedOut_Encoder_1)
# z = Sampling(name = 'Sampling_encoder')([z_mean, z_log_var])

# build model
encoder_1 = keras.Model([encoder_parameter_inputs, encoder_spectrum_inputs], [z_mean, z_log_var], name="encoder_1")
encoder_1.summary()
# Out:
# Model: "encoder_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_parameter_inputs (Input [(None, 2)]          0
# __________________________________________________________________________________________________
# encoder_spectrum_inputs (InputL [(None, 144)]        0
# __________________________________________________________________________________________________
# dense_parameter_1 (Dense)       (None, 64)           192         encoder_parameter_inputs[0][0]
# __________________________________________________________________________________________________
# dense_spectrum_1 (Dense)        (None, 64)           9280        encoder_spectrum_inputs[0][0]
# __________________________________________________________________________________________________
# dense_parameter_2 (Dense)       (None, 32)           2080        dense_parameter_1[0][0]
# __________________________________________________________________________________________________
# dense_spectrum_2 (Dense)        (None, 32)           2080        dense_spectrum_1[0][0]
# __________________________________________________________________________________________________
# dense_parameter_3 (Dense)       (None, 16)           528         dense_parameter_2[0][0]
# __________________________________________________________________________________________________
# dense_spectrum_3 (Dense)        (None, 16)           528         dense_spectrum_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32)           0           dense_parameter_3[0][0]
#                                                                  dense_spectrum_3[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 7)            231         concatenate[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 7)            231         concatenate[0][0]
# ==================================================================================================
# Total params: 15,150
# Trainable params: 15,150
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
"""
Encoder 2 (spectrum)
"""
# spectrum
encoder_spectrum_inputs = layers.Input(shape=(144,),name = 'encoder_spectrum_inputs')
x_spectrum = layers.Dense(64, activation="relu", name = 'dense_spectrum_1')(encoder_spectrum_inputs)
x_spectrum = layers.Dense(32, activation="relu", name = 'dense_spectrum_2')(x_spectrum)
x_spectrum = layers.Dense(16, activation="relu", name = 'dense_spectrum_3')(x_spectrum)

# sampling
z_mean = layers.Dense(10*latent_dim, name="z_mean")(x_spectrum)
z_log_var = layers.Dense(10*latent_dim, name="z_log_var")(x_spectrum)
z_weight = layers.Dense(10, name="z_weight")(x_spectrum)
# z = Sampling(name = 'Sampling_encoder')([z_mean, z_log_var])

# build model
encoder_2 = keras.Model(encoder_spectrum_inputs, [z_mean, z_log_var, z_weight], name="encoder_2")
encoder_2.summary()
# Out:
# Model: "encoder_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_spectrum_inputs (InputL [(None, 144)]        0
# __________________________________________________________________________________________________
# dense_spectrum_1 (Dense)        (None, 64)           9280        encoder_spectrum_inputs[0][0]
# __________________________________________________________________________________________________
# dense_spectrum_2 (Dense)        (None, 32)           2080        dense_spectrum_1[0][0]
# __________________________________________________________________________________________________
# dense_spectrum_3 (Dense)        (None, 16)           528         dense_spectrum_2[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 70)           1190        dense_spectrum_3[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 70)           1190        dense_spectrum_3[0][0]
# __________________________________________________________________________________________________
# z_weight (Dense)                (None, 10)           170         dense_spectrum_3[0][0]
# ==================================================================================================
# Total params: 14,438
# Trainable params: 14,438
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
"""
Decoder Model (latent + spectrum)
"""
latent_dim_2 = 2

decoder_latent_inputs = keras.Input(shape=(latent_dim,),name = 'decoder_latent_inputs')
x_latent = layers.Dense(64, activation="relu", name = 'dense_1')(decoder_latent_inputs)
x_latent = layers.Dense(32, activation="relu", name = 'dense_2')(x_latent)
x_latent = layers.Dense(16, activation="relu", name = 'dense_3')(x_latent)

# spectrum
decoder_spectrum_inputs = layers.Input(shape=(144,),name = 'decoder_spectrum_inputs')
x_spectrum = layers.Dense(64, activation="relu", name = 'dense_spectrum_1')(decoder_spectrum_inputs)
x_spectrum = layers.Dense(32, activation="relu", name = 'dense_spectrum_2')(x_spectrum)
x_spectrum = layers.Dense(16, activation="relu", name = 'dense_spectrum_3')(x_spectrum)

# merged
mergedOut_Decoder = Concatenate()([x_latent,x_spectrum])

z2_mean = layers.Dense(latent_dim_2, name="z_mean")(mergedOut_Decoder)
z2_log_var = layers.Dense(latent_dim_2, name="z_log_var")(mergedOut_Decoder)
# z2 = Sampling(name = 'Sampling_decoder')([z2_mean, z2_log_var])

decoder = keras.Model([decoder_latent_inputs, decoder_spectrum_inputs], [z2_mean, z2_log_var], name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# decoder_latent_inputs (InputLay [(None, 7)]          0
# __________________________________________________________________________________________________
# decoder_spectrum_inputs (InputL [(None, 144)]        0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           512         decoder_latent_inputs[0][0]
# __________________________________________________________________________________________________
# dense_spectrum_1 (Dense)        (None, 64)           9280        decoder_spectrum_inputs[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_spectrum_2 (Dense)        (None, 32)           2080        dense_spectrum_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           528         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_spectrum_3 (Dense)        (None, 16)           528         dense_spectrum_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32)           0           dense_3[0][0]
#                                                                  dense_spectrum_3[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            66          concatenate_1[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            66          concatenate_1[0][0]
# ==================================================================================================
# Total params: 15,140
# Trainable params: 15,140
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class CVAE(keras.Model):
    def __init__(self, encoder1, encoder2, decoder, **kwargs):
        super(CVAE, self).__init__(**kwargs)
        self.encoder1 = encoder1  #(parameter + spectrum)
        self.encoder2 = encoder2  #(spectrum)
        self.decoder = decoder    #(latent + spectrum)
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
                ]

    def train_step(self, data):
        x, y = data
        with tf.GradientTape() as tape:
            SMALL_CONSTANT = 1e-12 # necessary to prevent the division by zero in many operations 
            
            # encoder1: 
            # input: [parameter, spectrum]
            # output: [mean, log_var]
            # mean.shape= (N, 15)  log_var.shape= (N, 15)   D(latent space) = 15
            z1_mean, z1_log_var = self.encoder1(x)  #(parameter + spectrum)
            
            # GET q(z|x,y)   #(parameter + spectrum)
            temp_var_q = SMALL_CONSTANT + tf.exp(z1_log_var)
            mvn_q = tfp.distributions.MultivariateNormalDiag(
                          loc=z1_mean,
                          scale_diag=tf.sqrt(temp_var_q))
            
            z1 = mvn_q.sample()
            
            # encoder2: 
            # input: spectrum
            # output: [mean, log_var, weight]
            # mean.shape= (N, 10*15)  log_var.shape= (N, 10*15) weight.shape= (N, 10)  
            # D(latent space)=15, D(mixture component)=10
            z2_mean, z2_log_var, z2_weight = self.encoder2(x[1])  #(spectrum)

            # mean->reshape= (N, 10, 15  log_var->reshape= (N, 10, 15) for create mixture model
            z2_mean = tf.reshape(z2_mean, (-1, 10, 7))
            z2_log_var = tf.reshape(z2_log_var, (-1, 10, 7))
            z2_weight = tf.reshape(z2_weight, (-1, 10))

            # Get r1(z|y) mixture model   #(spectrum)
            temp_var_r1 = SMALL_CONSTANT + tf.exp(z2_log_var)
            bimix_gauss = tfp.distributions.MixtureSameFamily(
                          mixture_distribution=tfp.distributions.Categorical(logits=z2_weight),
                          components_distribution=tfp.distributions.MultivariateNormalDiag(
                          loc=z2_mean,
                          scale_diag=tf.sqrt(temp_var_r1)))
            
            z2 = bimix_gauss.sample()
            
            # decoder: 
            # input: [latent, spectrum]
            # output: [mean, log_var]
            # mean.shape= (N, 2)  log_var.shape= (N, 2) 
            reconstruction_mean, reconstruction_var = self.decoder([z1, x[1]])      #(latent + spectrum)
            
            # GET r2(x|z,y)    #(latent + spectrum)
            temp_var_r2 = SMALL_CONSTANT + tf.exp(reconstruction_var)
            reconstruction_parameter = tfp.distributions.MultivariateNormalDiag(
                                     loc=reconstruction_mean,
                                     scale_diag= tf.sqrt(temp_var_r2))
            
            r2 = reconstruction_parameter.sample()
        
            log_q_q = mvn_q.log_prob(z1)
            log_r1_q = bimix_gauss.log_prob(z1)               # evaluate the log prob of r1 at the q samples(z1)
            kl_loss = tf.reduce_mean(log_q_q - log_r1_q)      # average over batch
            
            reconstruction_parameter_loss = reconstruction_parameter.log_prob(y)
            reconstruction_loss = -1.0*tf.reduce_mean(reconstruction_parameter_loss)
            
            total_loss = reconstruction_loss + kl_loss
            
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
"""
Model Training
"""
cvae = CVAE(encoder_1,encoder_2,decoder)
cvae.compile(optimizer=keras.optimizers.Adam())
# vae.compile(optimizer=keras.optimizers.Adadelta())

check_list=[]
csv_logger = CSVLogger("./Training_loss/CVAE_1DCNN_training_log_v2.csv")
check_list.append(csv_logger)

# %%
# %%time
cvae.fit(x = [y_train, x_train],
         y = y_train,
         batch_size=1000,
         epochs=10,
         verbose=1,
         shuffle=True)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/distributions/distribution.py:298: calling MultivariateNormalDiag.__init__ (from tensorflow_probability.python.distributions.mvn_diag) with scale_identity_multiplier is deprecated and will be removed after 2020-01-01.
# Instructions for updating:
# `scale_identity_multiplier` is deprecated; please combine it with `scale_diag` directly instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/linalg/linear_operator_diag.py:175: calling LinearOperator.__init__ (from tensorflow.python.ops.linalg.linear_operator) with graph_parents is deprecated and will be removed in a future version.
# Instructions for updating:
# Do not pass `graph_parents`.  They will  no longer be used.
# 9000/9000 [==============================] - 62s 7ms/step - loss: 9.1603 - reconstruction_loss: 4.9936 - kl_loss: 0.1493
# Epoch 2/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 3.7122 - reconstruction_loss: 3.6191 - kl_loss: 4.0433e-04
# Epoch 3/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 3.4264 - reconstruction_loss: 3.3716 - kl_loss: 1.9230e-04
# Epoch 4/10
# 9000/9000 [==============================] - 58s 6ms/step - loss: 3.2394 - reconstruction_loss: 3.2021 - kl_loss: 1.8386e-04
# Epoch 5/10
# 9000/9000 [==============================] - 58s 6ms/step - loss: 3.0936 - reconstruction_loss: 3.0645 - kl_loss: 1.8666e-04
# Epoch 6/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.9809 - reconstruction_loss: 2.9507 - kl_loss: 1.9007e-04
# Epoch 7/10
# 9000/9000 [==============================] - 58s 6ms/step - loss: 2.8672 - reconstruction_loss: 2.8389 - kl_loss: 1.8470e-04
# Epoch 8/10
# 9000/9000 [==============================] - 58s 6ms/step - loss: 2.7615 - reconstruction_loss: 2.7369 - kl_loss: 1.8791e-04
# Epoch 9/10
# 9000/9000 [==============================] - 58s 6ms/step - loss: 2.6702 - reconstruction_loss: 2.6495 - kl_loss: 1.8401e-04
# Epoch 10/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.5936 - reconstruction_loss: 2.5743 - kl_loss: 1.8444e-04
# CPU times: user 12min 41s, sys: 1min 54s, total: 14min 35s
# Wall time: 9min 51s

# %%
scale_steps = np.logspace(-3, 0, 10)

for scale in scale_steps:
    x_train_gen = np.random.normal(x_train, np.sqrt(x_train)*scale)
    cvae.fit(x = [y_train, x_train_gen],
             y = y_train,
             batch_size=1000,
             epochs=10,
             verbose=1,
             shuffle=True)
# Out:
# Epoch 1/10
# 9000/9000 [==============================] - 58s 6ms/step - loss: 2.5431 - reconstruction_loss: 2.5275 - kl_loss: 1.9248e-04
# Epoch 2/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.6380 - reconstruction_loss: 3.2778 - kl_loss: 1.8821e-04
# Epoch 3/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 3.9877 - reconstruction_loss: 3.8588 - kl_loss: 1.7892e-04
# Epoch 4/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 3.5719 - reconstruction_loss: 3.5236 - kl_loss: 1.8376e-04
# Epoch 5/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 3.3932 - reconstruction_loss: 3.3601 - kl_loss: 1.8550e-04
# Epoch 6/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 3.2734 - reconstruction_loss: 3.2465 - kl_loss: 1.8682e-04
# Epoch 7/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.1753 - reconstruction_loss: 3.1571 - kl_loss: 1.7854e-04
# Epoch 8/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.0964 - reconstruction_loss: 3.0792 - kl_loss: 1.8479e-04
# Epoch 9/10
# 9000/9000 [==============================] - 61s 7ms/step - loss: 3.0568 - reconstruction_loss: 3.0835 - kl_loss: 1.8858e-04
# Epoch 10/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.0223 - reconstruction_loss: 2.9901 - kl_loss: 1.8265e-04
# Epoch 1/10
# 9000/9000 [==============================] - 61s 7ms/step - loss: 2.9881 - reconstruction_loss: 2.9717 - kl_loss: 1.8069e-04
# Epoch 2/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.9304 - reconstruction_loss: 2.9174 - kl_loss: 1.8803e-04
# Epoch 3/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.8805 - reconstruction_loss: 2.8707 - kl_loss: 1.8501e-04
# Epoch 4/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.8427 - reconstruction_loss: 2.8356 - kl_loss: 1.8770e-04
# Epoch 5/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.8132 - reconstruction_loss: 2.8052 - kl_loss: 1.8763e-04
# Epoch 6/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.7853 - reconstruction_loss: 2.7771 - kl_loss: 1.7529e-04
# Epoch 7/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.7556 - reconstruction_loss: 2.7495 - kl_loss: 1.8488e-04
# Epoch 8/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.7258 - reconstruction_loss: 2.7185 - kl_loss: 1.8867e-04
# Epoch 9/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.6921 - reconstruction_loss: 2.6833 - kl_loss: 1.8605e-04
# Epoch 10/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.6586 - reconstruction_loss: 2.6494 - kl_loss: 1.8181e-04
# Epoch 1/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.8818 - reconstruction_loss: 2.8588 - kl_loss: 1.8490e-04
# Epoch 2/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.8009 - reconstruction_loss: 2.7856 - kl_loss: 1.8543e-04
# Epoch 3/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.7395 - reconstruction_loss: 2.7232 - kl_loss: 1.8567e-04
# Epoch 4/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.6839 - reconstruction_loss: 2.6724 - kl_loss: 1.8459e-04
# Epoch 5/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.6433 - reconstruction_loss: 2.6352 - kl_loss: 1.8331e-04
# Epoch 6/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.6085 - reconstruction_loss: 2.6026 - kl_loss: 1.8626e-04
# Epoch 7/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.5819 - reconstruction_loss: 2.5744 - kl_loss: 1.7744e-04
# Epoch 8/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.5520 - reconstruction_loss: 2.5427 - kl_loss: 1.8416e-04
# Epoch 9/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.5190 - reconstruction_loss: 2.5118 - kl_loss: 1.8249e-04
# Epoch 10/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.4930 - reconstruction_loss: 2.4862 - kl_loss: 1.7613e-04
# Epoch 1/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.8727 - reconstruction_loss: 2.8398 - kl_loss: 1.8087e-04
# Epoch 2/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.7861 - reconstruction_loss: 2.7723 - kl_loss: 1.7722e-04
# Epoch 3/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.7426 - reconstruction_loss: 2.7333 - kl_loss: 1.8494e-04
# Epoch 4/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.7078 - reconstruction_loss: 2.6996 - kl_loss: 1.8013e-04
# Epoch 5/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.6772 - reconstruction_loss: 2.6729 - kl_loss: 1.7664e-04
# Epoch 6/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.6566 - reconstruction_loss: 2.6515 - kl_loss: 1.8253e-04
# Epoch 7/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.6396 - reconstruction_loss: 2.6342 - kl_loss: 1.8087e-04
# Epoch 8/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.6230 - reconstruction_loss: 2.6185 - kl_loss: 1.8296e-04
# Epoch 9/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.6085 - reconstruction_loss: 2.6039 - kl_loss: 1.8032e-04
# Epoch 10/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.5952 - reconstruction_loss: 2.5910 - kl_loss: 1.8840e-04
# Epoch 1/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.0824 - reconstruction_loss: 3.0423 - kl_loss: 1.8294e-04
# Epoch 2/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.9818 - reconstruction_loss: 2.9720 - kl_loss: 1.8531e-04
# Epoch 3/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.9461 - reconstruction_loss: 2.9392 - kl_loss: 1.8252e-04
# Epoch 4/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.9220 - reconstruction_loss: 2.9155 - kl_loss: 1.7753e-04
# Epoch 5/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.9021 - reconstruction_loss: 2.8965 - kl_loss: 1.8936e-04
# Epoch 6/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.8843 - reconstruction_loss: 2.8794 - kl_loss: 1.8035e-04
# Epoch 7/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.8683 - reconstruction_loss: 2.8644 - kl_loss: 1.8179e-04
# Epoch 8/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.8533 - reconstruction_loss: 2.8509 - kl_loss: 1.8355e-04
# Epoch 9/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 2.8425 - reconstruction_loss: 2.8405 - kl_loss: 1.7597e-04
# Epoch 10/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 2.8333 - reconstruction_loss: 2.8309 - kl_loss: 1.8071e-04
# Epoch 1/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.4213 - reconstruction_loss: 3.3795 - kl_loss: 1.7713e-04
# Epoch 2/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.3251 - reconstruction_loss: 3.3175 - kl_loss: 1.7841e-04
# Epoch 3/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.2955 - reconstruction_loss: 3.2871 - kl_loss: 1.8509e-04
# Epoch 4/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.2652 - reconstruction_loss: 3.2616 - kl_loss: 1.7775e-04
# Epoch 5/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.2477 - reconstruction_loss: 3.2442 - kl_loss: 1.7693e-04
# Epoch 6/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.2334 - reconstruction_loss: 3.2313 - kl_loss: 1.8540e-04
# Epoch 7/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 3.2223 - reconstruction_loss: 3.2206 - kl_loss: 1.8391e-04
# Epoch 8/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.2126 - reconstruction_loss: 3.2117 - kl_loss: 1.6981e-04
# Epoch 9/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.2039 - reconstruction_loss: 3.2023 - kl_loss: 1.6910e-04
# Epoch 10/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.1951 - reconstruction_loss: 3.1943 - kl_loss: 1.7751e-04
# Epoch 1/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.9421 - reconstruction_loss: 3.8914 - kl_loss: 1.7985e-04
# Epoch 2/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.8462 - reconstruction_loss: 3.8405 - kl_loss: 1.7791e-04
# Epoch 3/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 3.8268 - reconstruction_loss: 3.8234 - kl_loss: 1.7524e-04
# Epoch 4/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.8141 - reconstruction_loss: 3.8120 - kl_loss: 1.8641e-04
# Epoch 5/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.8048 - reconstruction_loss: 3.8042 - kl_loss: 1.8687e-04
# Epoch 6/10
# 9000/9000 [==============================] - 59s 7ms/step - loss: 3.7981 - reconstruction_loss: 3.7976 - kl_loss: 1.8131e-04
# Epoch 7/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.7926 - reconstruction_loss: 3.7905 - kl_loss: 1.7950e-04
# Epoch 8/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 3.7845 - reconstruction_loss: 3.7838 - kl_loss: 1.7656e-04
# Epoch 9/10
# 9000/9000 [==============================] - 61s 7ms/step - loss: 3.7791 - reconstruction_loss: 3.7783 - kl_loss: 1.7919e-04
# Epoch 10/10
# 9000/9000 [==============================] - 64s 7ms/step - loss: 3.7739 - reconstruction_loss: 3.7735 - kl_loss: 1.8462e-04
# Epoch 1/10
# 9000/9000 [==============================] - 64s 7ms/step - loss: 4.3979 - reconstruction_loss: 4.3654 - kl_loss: 1.7951e-04
# Epoch 2/10
# 9000/9000 [==============================] - 64s 7ms/step - loss: 4.3427 - reconstruction_loss: 4.3404 - kl_loss: 1.7775e-04
# Epoch 3/10
# 9000/9000 [==============================] - 64s 7ms/step - loss: 4.3340 - reconstruction_loss: 4.3335 - kl_loss: 1.7772e-04
# Epoch 4/10
# 9000/9000 [==============================] - 64s 7ms/step - loss: 4.3298 - reconstruction_loss: 4.3292 - kl_loss: 1.7317e-04
# Epoch 5/10
# 9000/9000 [==============================] - 64s 7ms/step - loss: 4.3268 - reconstruction_loss: 4.3258 - kl_loss: 1.7765e-04
# Epoch 6/10
# 9000/9000 [==============================] - 63s 7ms/step - loss: 4.3238 - reconstruction_loss: 4.3233 - kl_loss: 1.6954e-04
# Epoch 7/10
# 9000/9000 [==============================] - 64s 7ms/step - loss: 4.3217 - reconstruction_loss: 4.3211 - kl_loss: 1.7596e-04
# Epoch 8/10
# 9000/9000 [==============================] - 62s 7ms/step - loss: 4.3197 - reconstruction_loss: 4.3193 - kl_loss: 1.7309e-04
# Epoch 9/10
# 9000/9000 [==============================] - 60s 7ms/step - loss: 4.3182 - reconstruction_loss: 4.3178 - kl_loss: 1.8087e-04
# Epoch 10/10
# 9000/9000 [==============================] - 64s 7ms/step - loss: 4.3168 - reconstruction_loss: 4.3164 - kl_loss: 1.8233e-04
# Epoch 1/10
# 9000/9000 [==============================] - 65s 7ms/step - loss: 4.6044 - reconstruction_loss: 4.5923 - kl_loss: 1.7648e-04
# Epoch 2/10
# 9000/9000 [==============================] - 63s 7ms/step - loss: 4.5835 - reconstruction_loss: 4.5821 - kl_loss: 1.7135e-04
# Epoch 3/10
# 9000/9000 [==============================] - 62s 7ms/step - loss: 4.5766 - reconstruction_loss: 4.5752 - kl_loss: 1.7659e-04
# Epoch 4/10
# 4310/9000 [=============>................] - ETA: 31s - loss: 4.5714 - reconstruction_loss: 4.5714 - kl_loss: 1.7769e-04

# %%
for i in range(5):
    x_train_gen = np.random.poisson(x_train)
    cvae.fit(x = [y_train, x_train_gen],
             y = y_train,
             batch_size=1000,
             epochs=1,
             verbose=1,
             shuffle=True)

# %%
path = './CVAE/DNN_{}'
index = 1
while os.path.isdir(path.format(index)):
    index += 1
path = path.format(index)
cvae.encoder1.save(path + "/encoder_1_test_v2.h5")
cvae.encoder2.save(path + "/encoder_2_test_v2.h5")
cvae.decoder.save(path + "/decoder_test_v2.h5")
