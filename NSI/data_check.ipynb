# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['agg.path.chunksize'] = 10000

# %%
data = np.load("./nsi_data/sample_nsi_regression_1e7_v1.npz")

# %%
features = data.files[8:]

# %%
features
# Out:
# ['theta12', 'theta13', 'theta23', 'delta', 'sdm', 'ldm', 'mumu', 'emu', 'etau']

# %%
for i, f1 in enumerate(features):
    plt.hist(data[f1][:100000], bins = 100)
    plt.xlabel(f1)
    plt.show()

# %%
for i, f1 in enumerate(features):
    for f2 in features[i+1:]:
        print(f1, f2)
        plt.scatter(data[f1][:10000], data[f2][:10000])
        plt.show()
# Out:
# theta12 theta13
# theta12 theta23
# theta12 delta
# theta12 sdm
# theta12 ldm
# theta12 mumu
# theta12 emu
# theta12 etau
# theta13 theta23
# theta13 delta
# theta13 sdm
# theta13 ldm
# theta13 mumu
# theta13 emu
# theta13 etau
# theta23 delta
# theta23 sdm
# theta23 ldm
# theta23 mumu
# theta23 emu
# theta23 etau
# delta sdm
# delta ldm
# delta mumu
# delta emu
# delta etau
# sdm ldm
# sdm mumu
# sdm emu
# sdm etau
# ldm mumu
# ldm emu
# ldm etau
# mumu emu
# mumu etau
# emu etau
