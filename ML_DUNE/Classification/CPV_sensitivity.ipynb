# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
exposure = ['_p25', '_p5', '', '_t2', '_t4']
plt.figure(figsize = (20,10))
for ex in exposure:
    data = np.load('/home/ML4NO/Data/cpv_sensitivity_globes{}.npz'.format(ex))
    x = data['delta_cp']/180
    plt.plot(x, data['OFF_DU'], label='GLoBES DUNE Asimov{}'.format(ex))
#     plt.plot(x, data['OFF_T2'],'b', label='GLoBES T2HK Asimov')
#     plt.plot(x, data['OFF_DUT2'],'r', label='GLoBES DUT2 Asimov')
# plt.plot(np.linspace(-1,1,100),np.full(100,10), label=r'$5 \sigma $')
plt.title('CPV GLoBES Asimov with different time scale', fontsize=15)
plt.xlabel(r'True $\delta / \pi $', fontsize=15)
plt.ylabel(r'$\Delta\chi^2_{cpv} $', fontsize=15)
plt.ylim(0, 25)
plt.legend()
plt.show()
