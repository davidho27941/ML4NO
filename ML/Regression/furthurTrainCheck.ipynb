# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('/home/ML4NO/ML/Regression/models_furthurTrain/0804_theta23_5_result.npy', allow_pickle=True)
data = data.item()

# %%
plt.semilogx(data['scale_steps'], data['before_triain_loss'],'.', label='before_train_loss')
plt.semilogx(data['scale_steps'], data['after_train_loss'],'.', label='after_train_loss')
plt.xlabel('std value add on data')
plt.ylabel('MSE')
plt.legend()
plt.title('theta23 furthurTrain')
plt.show()
