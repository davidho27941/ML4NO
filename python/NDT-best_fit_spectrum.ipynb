# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
#filename = "best_fit_spectrum_deltacp_DUNE"
#filename = "best_fit_spectrum_deltacp_T2HK"
filename = "best_fit_spectrum_deltacp_DUT2"
#filename = "best_fit_spectrum_theta23_DUNE"
#filename = "best_fit_spectrum_theta23_T2HK"
#filename = "best_fit_spectrum_theta23_DUT2"

# %%
#Import txt檔
f = open("/globes-3.2.18/examples/" + filename+".dat")

# %%
theta12_true = []
theta13_true = []
theta23_true = []
delta_true = []
sdm_true = []
ldm_true = []

chi2 = []

theta12_fit = []
theta13_fit = []
theta23_fit = []
delta_fit = []
sdm_fit = []
ldm_fit = []

ve_dune_poisson = []
vebar_dune_poisson = []
vu_dune_poisson = []
vubar_dune_poisson = []
ve_t2hk_poisson= []
vu_t2hk_poisson = []
vebar_t2hk_poisson = []
vubar_t2hk_poisson = []


while True:
    s = f.readline().split()
    array = []
    for j in range(len(s)) :
        array.append(float(s[j]))
    if(len(array)>0):
        theta12_true.append(array[0])
        theta13_true.append(array[1])
        theta23_true.append(array[2])
        delta_true.append(array[3])
        sdm_true.append(array[4])
        ldm_true.append(array[5])

        chi2.append(array[6])

        theta12_fit.append(array[7])
        theta13_fit.append(array[8])
        theta23_fit.append(array[9])
        delta_fit.append(array[10])
        sdm_fit.append(array[11])
        ldm_fit.append(array[12])
        
        ve_dune_poisson.append(array[0+12:66+12])
        vebar_dune_poisson.append(array[66+12:132+12])
        vu_dune_poisson.append(array[132+12:198+12])
        vubar_dune_poisson.append(array[198+12:264+12])
        ve_t2hk_poisson.append(array[264+12:272+12])
        vu_t2hk_poisson.append(array[272+12:284+12])
        vebar_t2hk_poisson.append(array[284+12:292+12])
        vubar_t2hk_poisson.append(array[292+12:304+12])
    else:
        break

# %%
#輸出全部資料為npz檔
np.savez("/globes-3.2.18/examples/python/output/"+filename,
        theta12_true = theta12_true,
        theta13_true = theta13_true,
        theta23_true = theta23_true,
        delta_true = delta_true,
        sdm_true = sdm_true,
        ldm_true = ldm_true,

        chi2 = chi2,

        theta12_fit = theta12_fit,
        theta13_fit = theta13_fit,
        theta23_fit = theta23_fit,
        delta_fit = delta_fit,
        sdm_fit = sdm_fit,
        ldm_fit = ldm_fit,
         
        ve_dune_poisson = ve_dune_poisson,
        vebar_dune_poisson = vebar_dune_poisson,
        vu_dune_poisson = vu_dune_poisson,
        vubar_dune_poisson = vubar_dune_poisson,
        ve_t2hk_poisson= ve_t2hk_poisson,
        vu_t2hk_poisson = vu_t2hk_poisson,
        vebar_t2hk_poisson = vebar_t2hk_poisson,
        vubar_t2hk_poisson = vubar_t2hk_poisson,
        )
# Out:
# /root/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# # Test

# %%
data = np.load('/globes-3.2.18/examples/python/output/best_fit_spectrum_deltacp_DUNE.npz')

# %%
data['delta_true']
# Out:
# array([360., 360., 360., 360., 360., 360., 360., 360., 360., 360., 360.,
#        360., 360., 360., 360., 360., 360., 360., 360., 360., 360., 360.,
#        360., 360., 360., 360., 360., 360., 360., 360., 360., 360., 360.,
#        360., 360., 360., 360., 360., 360., 360., 360., 360., 360., 360.,
#        360., 360., 360., 360., 360., 360., 360., 360., 360., 360., 360.,
#        360., 360., 360., 360., 360., 360., 360., 360., 360., 360., 360.,
#        360., 360., 360., 360., 360., 360., 360., 360., 360., 360., 360.,
#        360., 360., 360., 360., 360., 360., 360., 360., 360., 360., 360.,
#        360., 360., 360., 360., 360., 360., 360., 360., 360., 360., 360.,
#        360.])

# %%
data.files
# Out:
# ['theta12_true',
#  'theta13_true',
#  'theta23_true',
#  'delta_true',
#  'sdm_true',
#  'ldm_true',
#  'chi2',
#  'theta12_fit',
#  'theta13_fit',
#  'theta23_fit',
#  'delta_fit',
#  'sdm_fit',
#  'ldm_fit',
#  've_dune_poisson',
#  'vebar_dune_poisson',
#  'vu_dune_poisson',
#  'vubar_dune_poisson',
#  've_t2hk_poisson',
#  'vu_t2hk_poisson',
#  'vebar_t2hk_poisson',
#  'vubar_t2hk_poisson']

# %%
len(data['vubar_t2hk_poisson'])
# Out:
# 100

# %%
plt.figure(figsize = (5,5))
plt.hist(data['delta_true'],bins=100,color = "skyblue")
plt.xlabel(r'$\delta_true $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\delta_true{12} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\delta_true{12} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['theta13'],bins=100,color = "skyblue")
plt.xlabel(r'$\theta$', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\theta_{13} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\theta_{13} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['theta23'],bins=100,color = "skyblue")
plt.xlabel(r'$\theta $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\theta_{23} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\theta_{23} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['delta'],bins=100,color = "skyblue")
plt.xlabel(r'$\theta $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\delta_{CP} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\delta_{CP} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['sdm'],bins=100,color = "skyblue")
plt.xlabel(r'$10^-5  eV^2 $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\Delta m^2_{21} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\Delta m^2_{21} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['ldm'],bins=100,color = "skyblue")
plt.xlabel(r'$10^-5  eV^2 $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\Delta m^2_{31} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\Delta m^2_{31} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['ldm'][data['ldm']>0],bins=100,color = "skyblue")
plt.xlabel(r'$10^-5  eV^2 $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\Delta m^2_{31} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\Delta m^2_{31} $')

# %%
data.files[13:]
# Out:
# ['ve_dune_poisson',
#  'vebar_dune_poisson',
#  'vu_dune_poisson',
#  'vubar_dune_poisson',
#  've_t2hk_poisson',
#  'vu_t2hk_poisson',
#  'vebar_t2hk_poisson',
#  'vubar_t2hk_poisson']

# %%
# Spectrum 
plt.figure(figsize = (10,50))
feature = data.files[13:]
n = 0
for i in feature:
    n = n+1
    plt.subplot(len(feature),1,n)
    plt.xlabel('bin number', fontsize=15)
    plt.ylabel('#', fontsize=15)
    y = data[i][1]
    x = range(len(y))
    plt.plot(x,y)
    plt.title(i, fontsize=15)
