# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
#Import txt檔
f = open("/globes-3.2.18/examples/sample_classification.dat")

# %%
ve_dune = []
vebar_dune = []
vu_dune = []
vubar_dune = []
ve_t2hk = []
vu_t2hk = []
vebar_t2hk = []
vubar_t2hk = []
theta12 = []
theta13 = []
theta23 = []
delta = []
sdm = []
ldm = []
octant = []
cpv = []
mo = []

while True:
    s = f.readline().split()
    array = []
    for j in range(len(s)) :
        array.append(float(s[j]))
    if(len(array)>0):
        ve_dune.append(array[0:66])
        vebar_dune.append(array[66:132])
        vu_dune.append(array[132:198])
        vubar_dune.append(array[198:264])
        ve_t2hk.append(array[264:272])
        vu_t2hk.append(array[272:284])
        vebar_t2hk.append(array[284:292])
        vubar_t2hk.append(array[292:304])
        theta12.append(array[304])
        theta13.append(array[305])
        theta23.append(array[306])
        delta.append(array[307])
        sdm.append(array[308])
        ldm.append(array[309])
        octant.append(array[310])
        cpv.append(array[311])
        mo.append(array[312])
    else:
        break

# %%
#輸出全部資料為npz檔
np.savez("/globes-3.2.18/examples/python/output/sample_classification",
         ve_dune = ve_dune,
         vebar_dune = vebar_dune,
         vu_dune = vu_dune,
         vubar_dune = vubar_dune,
         ve_t2hk = ve_t2hk,
         vu_t2hk = vu_t2hk,
         vebar_t2hk = vebar_t2hk,
         vubar_t2hk= vubar_t2hk,
         theta12 = theta12,
         theta13 = theta13,   
         theta23 = theta23,   
         delta = delta,
         sdm = sdm,   
         ldm = ldm,  
         octant = octant,
         cpv = cpv,   
         mo = mo  
        )

# %% [markdown]
# # Test

# %%
data = np.load('/globes-3.2.18/examples/python/output/sample_classification.npz')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['theta12'],bins=100,color = "skyblue")
plt.xlabel(r'$\theta $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\theta_{12} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\theta_{12} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['theta13'],bins=100,color = "skyblue")
plt.xlabel(r'$\theta$', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\theta_{13} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\theta_{13} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['theta23'],bins=100,color = "skyblue")
plt.xlabel(r'$\theta $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\theta_{23} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\theta_{23} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['delta'],bins=100,color = "skyblue")
plt.xlabel(r'$\theta $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\delta_{CP} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\delta_{CP} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['sdm'],bins=100,color = "skyblue")
plt.xlabel(r'$10^-5  eV^2 $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\Delta m^2_{21} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\Delta m^2_{21} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['ldm'],bins=100,color = "skyblue")
plt.xlabel(r'$10^-5  eV^2 $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\Delta m^2_{31} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\Delta m^2_{31} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['ldm'][data['ldm']>0],bins=100,color = "skyblue")
plt.xlabel(r'$10^-5  eV^2 $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\Delta m^2_{31} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\Delta m^2_{31} $')

# %%
# Spectrum 
plt.figure(figsize = (10,50))
feature = ['ve_dune','vebar_dune','vu_dune','vubar_dune','ve_t2hk','vu_t2hk','vebar_t2hk','vubar_t2hk']
n = 0
for i in feature:
    n = n+1
    plt.subplot(len(feature),1,n)
    plt.xlabel('bin number', fontsize=15)
    plt.ylabel('#', fontsize=15)
    y = data[i][1]
    x = range(len(y))
    plt.plot(x,y)
    plt.title(i, fontsize=15)

# %%
len(data['ve_dune'][0])
# Out:
# 66
