# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
#filename = "best_fit_spectrum_deltacp_theta23_DUNE"
#filename = "best_fit_spectrum_deltacp_theta23_T2HK"
filename = "best_fit_spectrum_deltacp_theta23_DUT2"

# %%
#Import txt檔
f = open("/globes-3.2.18/examples/" + filename+".dat")

# %%
theta12_true = []
theta13_true = []
theta23_true = []
delta_true = []
sdm_true = []
ldm_true = []

chi2 = []

theta12_fit = []
theta13_fit = []
theta23_fit = []
delta_fit = []
sdm_fit = []
ldm_fit = []

event_run_time = []

ve_dune_poisson = []
vebar_dune_poisson = []
vu_dune_poisson = []
vubar_dune_poisson = []
ve_t2hk_poisson= []
vu_t2hk_poisson = []
vebar_t2hk_poisson = []
vubar_t2hk_poisson = []

total_num = 1000

for i in range(total_num):
    s = f.readline().split()
    array = []
    for j in range(len(s)) :
        array.append(float(s[j]))
    if(len(array)>0):
        theta12_true.append(array[0])
        theta13_true.append(array[1])
        theta23_true.append(array[2])
        delta_true.append(array[3])
        sdm_true.append(array[4])
        ldm_true.append(array[5])

        chi2.append(array[6])

        theta12_fit.append(array[7])
        theta13_fit.append(array[8])
        theta23_fit.append(array[9])
        delta_fit.append(array[10])
        sdm_fit.append(array[11])
        ldm_fit.append(array[12])
        
        event_run_time.append(array[13])
        
        ve_dune_poisson.append(array[0+13:66+13])
        vebar_dune_poisson.append(array[66+13:132+13])
        vu_dune_poisson.append(array[132+13:198+13])
        vubar_dune_poisson.append(array[198+13:264+13])
        ve_t2hk_poisson.append(array[264+13:272+13])
        vu_t2hk_poisson.append(array[272+13:284+13])
        vebar_t2hk_poisson.append(array[284+13:292+13])
        vubar_t2hk_poisson.append(array[292+13:304+13])
    else:
        break

# %%
#輸出全部資料為npz檔
np.savez("/globes-3.2.18/examples/python/output/"+filename,
        theta12_true = theta12_true,
        theta13_true = theta13_true,
        theta23_true = theta23_true,
        delta_true = delta_true,
        sdm_true = sdm_true,
        ldm_true = ldm_true,

        chi2 = chi2,

        theta12_fit = theta12_fit,
        theta13_fit = theta13_fit,
        theta23_fit = theta23_fit,
        delta_fit = delta_fit,
        sdm_fit = sdm_fit,
        ldm_fit = ldm_fit,
        
        event_run_time = event_run_time, 
         
        ve_dune_poisson = ve_dune_poisson,
        vebar_dune_poisson = vebar_dune_poisson,
        vu_dune_poisson = vu_dune_poisson,
        vubar_dune_poisson = vubar_dune_poisson,
        ve_t2hk_poisson= ve_t2hk_poisson,
        vu_t2hk_poisson = vu_t2hk_poisson,
        vebar_t2hk_poisson = vebar_t2hk_poisson,
        vubar_t2hk_poisson = vubar_t2hk_poisson,
        )

# %% [markdown]
# # Test

# %%
data = np.load('/globes-3.2.18/examples/python/output/best_fit_spectrum_deltacp_theta23_DUT2.npz')

# %%
data['event_run_time']
# Out:
# array([19.629 , 15.4605, 17.4073, 16.4391, 15.4684, 16.441 , 18.9986,
#        17.3834, 18.5919, 17.0995, 14.524 , 15.1978, 14.1775, 17.5527,
#        15.6689, 15.2839, 17.172 , 19.0798, 13.7067, 16.0632, 16.2686,
#        13.2902, 16.2053, 16.8881, 17.4302, 17.4229, 17.5477, 15.2096,
#        17.0782, 15.788 , 17.4221, 15.966 , 16.2769, 18.7068, 17.5497,
#        15.4504, 14.7106, 16.4785, 16.5917, 14.9357, 15.5959, 16.5622,
#        14.7186, 16.4974, 17.4918, 15.9648, 14.4392, 14.7564, 16.9641,
#        18.9909, 18.3182, 17.2548, 16.4667, 15.6473, 15.6159, 13.7854,
#        15.8978, 15.9645, 14.3959, 15.4578, 19.0519, 20.5203, 16.5187,
#        14.2   , 16.8349, 16.0228, 14.9041, 15.2316, 16.8201, 17.6818,
#        18.287 , 16.4948, 14.497 , 14.9099, 14.9772, 20.7697, 16.3636,
#        14.6839, 17.4029, 14.4836, 15.4248, 17.5043, 14.9958, 16.6789,
#        14.9329, 14.295 , 15.0474, 22.7051, 15.1879, 19.3738, 15.8928,
#        17.1626, 20.4739, 14.3651, 14.8305, 17.088 , 16.0025, 15.6157,
#        16.848 , 16.5732, 18.22  , 16.3171, 20.087 , 15.3166, 14.2391,
#        16.1367, 17.4594, 15.4705, 16.8096, 20.3409, 15.6844, 16.6611,
#        15.8647, 17.5158, 20.1168, 20.7461, 16.5197, 16.3569, 19.3765,
#        16.1063, 16.4665, 16.0662, 18.6833, 14.8444, 18.8044, 20.6219,
#        18.5084, 14.2312, 16.2955, 20.0818, 14.3325, 21.167 , 14.3947,
#        14.7351, 14.0754, 15.409 , 21.2515, 17.0685, 22.354 , 14.0439,
#        15.4687, 18.3513, 16.8073, 16.4165, 17.6187, 13.7903, 17.7662,
#        14.5527, 15.1962, 16.9019, 21.08  , 15.2346, 15.091 , 14.8739,
#        14.0589, 14.7454, 17.752 , 12.88  , 15.9231, 17.8804, 19.7101,
#        16.6027, 14.6257, 17.5886, 15.2319, 16.6132, 16.5337, 19.3102,
#        18.4837, 15.8964, 14.3902, 16.0459, 18.9903, 24.6303, 15.2494,
#        14.2452, 21.0049, 16.5399, 15.1371, 14.7454, 16.3596, 19.2777,
#        15.3741, 17.4968, 17.4799, 15.5139, 14.0772, 15.6218, 16.5664,
#        15.5482, 16.3987, 15.132 , 16.4727, 15.4996, 16.5498, 15.4328,
#        16.7461, 19.926 , 16.6755, 21.087 , 16.94  , 14.7628, 19.8593,
#        16.1873, 15.4309, 15.0597, 17.8072, 16.9986, 16.2876, 14.5143,
#        15.9445, 15.2832, 16.2224, 13.7753, 14.4525, 15.6322, 14.726 ,
#        16.01  , 17.7229, 17.2439, 16.4924, 16.0561, 19.89  , 15.8397,
#        18.3657, 16.0204, 18.555 , 15.7605, 15.9583, 14.8989, 20.4344,
#        17.2257, 19.7235, 15.6239, 16.8796, 17.9225, 15.578 , 21.7735,
#        15.8098, 16.0571, 16.2498, 15.8847, 20.5458, 20.824 , 16.1862,
#        15.7792, 20.5427, 18.8923, 16.0181, 15.8575, 15.4457, 14.9177,
#        16.0465, 15.2949, 17.155 , 22.0634, 16.2599, 15.2953])

# %%
data.files
# Out:
# ['theta12_true',
#  'theta13_true',
#  'theta23_true',
#  'delta_true',
#  'sdm_true',
#  'ldm_true',
#  'chi2',
#  'theta12_fit',
#  'theta13_fit',
#  'theta23_fit',
#  'delta_fit',
#  'sdm_fit',
#  'ldm_fit',
#  'event_run_time',
#  've_dune_poisson',
#  'vebar_dune_poisson',
#  'vu_dune_poisson',
#  'vubar_dune_poisson',
#  've_t2hk_poisson',
#  'vu_t2hk_poisson',
#  'vebar_t2hk_poisson',
#  'vubar_t2hk_poisson']

# %%
len(data['ve_dune_poisson'][0])
# Out:
# 66

# %%
plt.figure(figsize = (5,5))
plt.hist(data['delta_true'],bins=100,color = "skyblue")
plt.xlabel(r'$\delta_true $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\delta_true{12} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\delta_true{12} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['delta_fit'],bins=100,color = "skyblue")
plt.xlabel(r'$\delta_fit$', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\delta_fit{13} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\delta_fit{13} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['theta23'],bins=100,color = "skyblue")
plt.xlabel(r'$\theta $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\theta_{23} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\theta_{23} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['delta'],bins=100,color = "skyblue")
plt.xlabel(r'$\theta $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\delta_{CP} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\delta_{CP} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['sdm'],bins=100,color = "skyblue")
plt.xlabel(r'$10^-5  eV^2 $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\Delta m^2_{21} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\Delta m^2_{21} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['ldm'],bins=100,color = "skyblue")
plt.xlabel(r'$10^-5  eV^2 $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\Delta m^2_{31} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\Delta m^2_{31} $')

# %%
plt.figure(figsize = (5,5))
plt.hist(data['ldm'][data['ldm']>0],bins=100,color = "skyblue")
plt.xlabel(r'$10^-5  eV^2 $', fontsize=15)
plt.ylabel('#', fontsize=15)
plt.title(r'$\Delta m^2_{31} $', fontsize=15)
# Out:
# Text(0.5, 1.0, '$\\Delta m^2_{31} $')

# %%
data.files[13:]
# Out:
# ['ve_dune_poisson',
#  'vebar_dune_poisson',
#  'vu_dune_poisson',
#  'vubar_dune_poisson',
#  've_t2hk_poisson',
#  'vu_t2hk_poisson',
#  'vebar_t2hk_poisson',
#  'vubar_t2hk_poisson']

# %%
# Spectrum 
plt.figure(figsize = (10,50))
feature = data.files[14:]
n = 0
for i in feature:
    n = n+1
    plt.subplot(len(feature),1,n)
    plt.xlabel('bin number', fontsize=15)
    plt.ylabel('#', fontsize=15)
    y = data[i][1]
    x = range(len(y))
    plt.plot(x,y)
    plt.title(i, fontsize=15)
